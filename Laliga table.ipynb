# %%
import requests
standing_url = "https://fbref.com/en/comps/12/La-Liga-Stats"

# %%
data = requests.get(standing_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
soup.select('table.stats_table')[0]

# %%
standings_table
# Out:
# <table class="stats_table sortable min_width" data-cols-to-freeze=",2" id="results2022-2023121_overall"> <caption>League Table Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label="Rank" class="poptip center" data-stat="rank" data-tip="Squad finish in competition&lt;br&gt;Finish within the league or competition.&lt;br&gt;For knockout competitions may show final round reached.&lt;br&gt;Colors and arrows represent promotion/relegation or qualifiation for continental cups.&lt;br&gt;Trophy indicates team won league whether by playoffs or by leading the table.&lt;br&gt;Star indicates topped table in league USING another means of naming champion." scope="col">Rk</th> <th aria-label="Squad" class="poptip center" data-stat="team" scope="col">Squad</th> <th aria-label="Matches Played" class="poptip center" data-stat="games" data-tip="Matches Played by the player
# ...

# %%
#finding all the <a> tags in the table
links = standings_table.find_all('a')        
#find all can only help in selecting alphabets unlike select helps in findin elements,ids etc
links = [l.get("href") for l in links] 
links = [l for l in links if '/squads/' in l] #to check use links
team_urls = [f"https://fbref.com{l}" for l in links] #takes each links and adds fbref before them

# %%
data = requests.get(team_urls[0])

# %%
import pandas as pd
matches = pd.read_html(data.text, match = 'Scores & Fixtures')#looks for specific string scores and fix..so it scans everythn)

# %%
matches[0]
# Out:
#           Date   Time     Comp           Round  Day Venue Result   GF   GA  \
# 0   2022-08-13  19:00  La Liga     Matchweek 1  Sat  Away      W  3.0  0.0
# 1   2022-08-18  20:45  Conf Lg  Play-off round  Thu  Home      W  4.0  2.0
# 2   2022-08-21  19:30  La Liga     Matchweek 2  Sun  Away      W  2.0  0.0
# 3   2022-08-25  21:00  Conf Lg  Play-off round  Thu  Away    NaN  NaN  NaN
# 4   2022-08-28  17:30  La Liga     Matchweek 3  Sun  Away    NaN  NaN  NaN
# 5   2022-09-04  18:30  La Liga     Matchweek 4  Sun  Home    NaN  NaN  NaN
# 6   2022-09-11  21:00  La Liga     Matchweek 5  Sun  Away    NaN  NaN  NaN
# 7   2022-09-18  16:15  La Liga     Matchweek 6  Sun  Home    NaN  NaN  NaN
# 8   2022-10-02    NaN  La Liga     Matchweek 7  Sun  Away    NaN  NaN  NaN
# 9   2022-10-09    NaN  La Liga     Matchweek 8  Sun  Away    NaN  NaN  NaN
# 10  2022-10-16    NaN  La Liga     Matchweek 9  Sun  Home    NaN  NaN  NaN
# ...

# %%
soup  = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/Villareal']
links
# Out:
# ['https://fbref.com/pt/squads/2a8183b3/Villarreal-Stats',
#  'https://fbref.com/en/squads/2a8183b3/Villarreal-Stats',
#  'https://fbref.com/fr/squads/2a8183b3/Villarreal-Stats',
#  'https://fbref.com/it/squads/2a8183b3/Villarreal-Stats',
#  'https://fbref.com/de/squads/2a8183b3/Villarreal-Stats',
#  'https://fbref.com/es/squads/2a8183b3/Villarreal-Stats',
#  'https://www.sports-reference.com/',
#  'https://www.baseball-reference.com/',
#  'https://www.pro-football-reference.com/',
#  'https://www.sports-reference.com/cfb/',
#  'https://www.basketball-reference.com/',
#  'https://www.sports-reference.com/cbb/',
#  'https://www.hockey-reference.com/',
#  'https://fbref.com/',
#  'https://www.sports-reference.com/blog/',
#  'https://stathead.com/?utm_source=web&utm_medium=fb&utm_campaign=sr-nav-bar-top-link',
#  'https://widgets.sports-reference.com/',
#  'https://www.sports-reference.com/feedback/',
# ...

# %%
shooting = pd.read_html(data.text, match = "Shooting")[0]

# %%
shooting.head() # here u can see the name of villareal (a team in spanish football league) players and their shots on target
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Raúl Albiol             es ESP                 DF             36-355
# 1      Daniel Parejo             es ESP                 MF             33-131
# 2    Alfonso Pedraza             es ESP                 DF             26-138
# 3     Gerónimo Rulli             ar ARG                 GK             30-097
# 4         Pau Torres             es ESP                 DF             25-221
#
#   Unnamed: 4_level_0 Standard                    ...                    \
#                  90s      Gls Sh SoT SoT% Sh/90  ...  Dist FK PK PKatt
# 0                2.0        0  1   0  0.0   0.5  ...  30.0  0  0     0
# 1                2.0        0  1   0  0.0   0.5  ...  21.0  0  0     0
# 2                2.0        0  2   0  0.0   1.0  ...  22.7  0  0     0
# ...

# %%
#DATA for multiple teams for many seasons

years = list(range(2021,2020,-1))
years
# Out:
# [2021]

# %%
len(all_matches)
# Out:
# 0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
#       1 for year in years:
# ----> 2     data = requests.get(standings_url)
#
# NameError: name 'requests' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 matches_df
#
# NameError: name 'matches_df' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 matches_df
#
# NameError: name 'matches_df' is not defined
